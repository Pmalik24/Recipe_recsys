# %%
import pandas as pd
pd.options.display.max_rows = 10
import numpy as np 
pd.set_option('display.max_colwidth', None)
import os
import re
import json


# https://www.kaggle.com/datasets/kaggle/recipe-ingredients-dataset/

# %%
with open('recipe_ingredients_dataset/train.json', 'r') as file:
    data = json.load(file)

# Create DataFrame
train_df = pd.DataFrame(data)

# %%
train_df
# Out:
#           id      cuisine  \
# 0      10259        greek
# 1      25693  southern_us
# 2      20130     filipino
# 3      22213       indian
# 4      13162       indian
# ...      ...          ...
# 39769  29109        irish
# 39770  11462      italian
# 39771   2238        irish
# 39772  41882      chinese
# 39773   2362      mexican
#
#                                                                                                                                                                                                                                                                                                                           ingredients
# 0                                                                                                                                                                                                      [romaine lettuce, black olives, grape tomatoes, garlic, pepper, purple onion, seasoning, garbanzo beans, feta cheese crumbles]
# ...

# %%
with open('recipe_ingredients_dataset/test.json', 'r') as file:
    data = json.load(file)

# Create DataFrame
test_df = pd.DataFrame(data)

# %%
test_df
# Out:
#          id  \
# 0     18009
# 1     28583
# 2     41580
# 3     29752
# 4     35687
# ...     ...
# 9939  30246
# 9940  36028
# 9941  22339
# 9942  42525
# 9943   1443
#
#                                                                                                                                                                                                                                                                                                  ingredients
# 0                                                                                                                                                                                                                                       [baking powder, eggs, all-purpose flour, raisins, milk, white sugar]
# ...

# %%
train_df.to_csv('train.csv', index=False)
test_df.to_csv('test.csv', index=False)

# %%
all_ingredieants = []

# %%
# CREATE THIS


#           eggs, cheese, lettuce, rice, .............., coke, pepsi, sprite.
# recipe 1   1,    0,    1,     1,  ..............,  0,    0,     0
# recipe 2   0,   1,    0,     1,  ..............,  0,    0,     0
# recipe 3
# recipe 4

# %%
# INPUT RECIPES     # RECCOMENDATION 
# sugar, butter, flour           # cake --> RIGHT  
# ===============================================================
# sugar, butter, flour           # pizza --> WRONG

# %%
df = pd.read_csv('archive/Food Ingredients and Recipe Dataset with Image Name Mapping.csv')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
full_df = pd.concat([train_df, test_df])
full_df
# Out:
#          id      cuisine  \
# 0     10259        greek
# 1     25693  southern_us
# 2     20130     filipino
# 3     22213       indian
# 4     13162       indian
# ...     ...          ...
# 9939  30246          NaN
# 9940  36028          NaN
# 9941  22339          NaN
# 9942  42525          NaN
# 9943   1443          NaN
#
#                                                                                                                                                                                                                                                                                   ingredients
# 0                                                                                                                                                              [romaine lettuce, black olives, grape tomatoes, garlic, pepper, purple onion, seasoning, garbanzo beans, feta cheese crumbles]
# ...

# %%
full_df.sort_values(by=['id'], ascending=True, inplace=True)

# %%
full_df.to_csv('full_df.csv', index=False)

# %%
with open('recipes_raw/recipes_raw_nosource_ar.json', 'r') as file:
    data = json.load(file)

# Create DataFrame
yaseen_df = pd.DataFrame(data)
